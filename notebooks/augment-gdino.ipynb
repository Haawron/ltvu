# %%
# %cd /data/gunsbrother/prjs/ltvu
# Out:
# /data/gunsbrother/prjs/ltvu

# %%
import pickle
from pathlib import Path

p_bboxes = Path('croppers/GroundingDINO/egonlq/results/egonlq-gdino')
p_pkl = next(p_bboxes.glob('*.pkl'))
bboxes = pickle.load(p_pkl.open('rb'))
bboxes
# Out:
# [[[[0.47305241227149963,
#     0.5816307067871094,
#     0.13975609838962555,
#     0.15924674272537231],
#    [0.1505167931318283,
#     0.41498804092407227,
#     0.06951552629470825,
#     0.1552773118019104],
#    [0.8367006182670593,
#     0.7309843301773071,
#     0.1652810126543045,
#     0.1657831072807312],
#    [0.49995964765548706,
#     0.9040216207504272,
#     0.08133213967084885,
#     0.16338543593883514],
#    [0.33914127945899963,
#     0.5814100503921509,
#     0.15185093879699707,
#     0.20811107754707336],
#    [0.5260784029960632,
#     0.8215842247009277,
#     0.061718378216028214,
#     0.13522300124168396],
#    [0.388414204120636,
#     0.41342857480049133,
#     0.4452016055583954,
#     0.8221810460090637],
#    [0.5002989172935486,
#     0.9031873345375061,
#     0.07938969135284424,
#     0.159736767411232]],
#   [0.6180133819580078,
#    0.5314885377883911,
#    0.3875807821750641,
#    0.4238133132457733,
#    0.4658677279949188,
# ...
