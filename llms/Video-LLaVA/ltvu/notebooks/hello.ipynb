# %%
import pandas as pd
from pathlib import Path

p_nlq_csv = Path('/data/gunsbrother/prjs/ltvu/tasks/Ego4D/EgoNLQ/csvs/nlq_val_v1.csv')
df_nlq = pd.read_csv(p_nlq_csv, header=0)
df_nlq['clip_uid'].isin(asd)
# Out:
#                                  video_uid  \
# 0     38737402-19bd-4689-9e74-3af391b15feb
# 1     38737402-19bd-4689-9e74-3af391b15feb
# 2     38737402-19bd-4689-9e74-3af391b15feb
# 3     38737402-19bd-4689-9e74-3af391b15feb
# 4     38737402-19bd-4689-9e74-3af391b15feb
# ...                                    ...
# 3869  000cd456-ff8d-499b-b0c1-4acead128a8b
# 3870  000cd456-ff8d-499b-b0c1-4acead128a8b
# 3871  000cd456-ff8d-499b-b0c1-4acead128a8b
# 3872  000cd456-ff8d-499b-b0c1-4acead128a8b
# 3873  000cd456-ff8d-499b-b0c1-4acead128a8b
#
#                                   clip_uid  video_start_sec  video_end_sec  \
# 0     93231c7e-1cf4-4a20-b1f8-9cc9428915b2            630.0         1110.0
# 1     93231c7e-1cf4-4a20-b1f8-9cc9428915b2            630.0         1110.0
# 2     93231c7e-1cf4-4a20-b1f8-9cc9428915b2            630.0         1110.0
# 3     93231c7e-1cf4-4a20-b1f8-9cc9428915b2            630.0         1110.0
# 4     93231c7e-1cf4-4a20-b1f8-9cc9428915b2            630.0         1110.0
# ...                                    ...              ...            ...
# 3869  bfea3e01-55f4-4744-a7c6-4494c7b99ef2            270.0          750.0
# 3870  bfea3e01-55f4-4744-a7c6-4494c7b99ef2            270.0          750.0
# 3871  bfea3e01-55f4-4744-a7c6-4494c7b99ef2            270.0          750.0
# 3872  bfea3e01-55f4-4744-a7c6-4494c7b99ef2            270.0          750.0
# 3873  bfea3e01-55f4-4744-a7c6-4494c7b99ef2            270.0          750.0
#
#       video_start_frame  video_end_frame  clip_start_sec  clip_end_sec  \
# 0                 18900            33300             0.0         480.0
# 1                 18900            33300             0.0         480.0
# 2                 18900            33300             0.0         480.0
# 3                 18900            33300             0.0         480.0
# 4                 18900            33300             0.0         480.0
# ...                 ...              ...             ...           ...
# 3869               8100            22500             0.0         480.0
# 3870               8100            22500             0.0         480.0
# 3871               8100            22500             0.0         480.0
# 3872               8100            22500             0.0         480.0
# 3873               8100            22500             0.0         480.0
#
#       clip_start_frame  clip_end_frame  ...  verb_x  slot_y verb_y  \
# 0                    0           14400  ...     put     NaN    NaN
# 1                    0           14400  ...    talk     NaN    NaN
# 2                    0           14400  ...     see     NaN    NaN
# 3                    0           14400  ...     put     NaN    NaN
# 4                    0           14400  ...    play     NaN    NaN
# ...                ...             ...  ...     ...     ...    ...
# 3869                 0           14400  ...   throw   floor    NaN
# 3870                 0           14400  ...    drag     NaN    NaN
# 3871                 0           14400  ...    talk     NaN    NaN
# 3872                 0           14400  ...     put     NaN    NaN
# 3873                 0           14400  ...    kick     NaN    NaN
#
#       q_clip_start_frame  q_clip_end_frame  q_duration_sec  q_duration_frame  \
# 0                  12750             12930        6.000000               181
# 1                  13950             14160        7.000000               211
# 2                   5217              5220        0.100000                 4
# 3                   5340              5520        6.000000               181
# 4                  11520             11792        9.066667               273
# ...                  ...               ...             ...               ...
# 3869                5499              5833       11.133333               335
# 3870                7526              7583        1.900000                58
# 3871               11939             12235        9.866667               297
# 3872                5540              5600        2.000000                61
# 3873                6542              6792        8.333333               251
#
#       q_coverage  query_idx                                 q_uid
# 0       0.012569          0  b6cd9eef-35e1-56af-bb3a-a9f847d9c1ef
# 1       0.014652          1  bdd63d88-18c7-5d23-b97f-ea0ae3e71d9a
# 2       0.000278          2  dc063347-dff6-5676-8437-9c653fa04e2b
# 3       0.012569          3  6683bb77-782d-524a-8015-f2ca7a773eb8
# 4       0.018957          0  7c6ab14f-5a73-531d-a93e-70328d84629f
# ...          ...        ...                                   ...
# 3869    0.023262          0  5324d1f6-37eb-5c18-87e0-fcf74011b7a8
# 3870    0.004027          1  75715a48-1d6e-5a32-b4f0-652c9bbfc642
# 3871    0.020624          2  4196a658-743a-5eef-a43e-4bb213f068e4
# 3872    0.004236          3  43deb2a5-a294-5ffa-8b36-f13face98f73
# 3873    0.017429          4  7c23b5ac-0498-5132-bd4f-15f619d33a4e
#
# [3874 rows x 32 columns]
